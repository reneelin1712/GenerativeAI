# %%
# !pip install wandb -qU

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: reneelin2020. Use `wandb login --relogin` to force relogin
# True

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard

# %%
class Discriminator(nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.disc = nn.Sequential(
            nn.Linear(in_features, 128),
            nn.LeakyReLU(0.01),
            nn.Linear(128, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.disc(x)


class Generator(nn.Module):
    def __init__(self, z_dim, img_dim):
        super().__init__()
        self.gen = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.LeakyReLU(0.01),
            nn.Linear(256, img_dim),
            nn.Tanh(),  # normalize inputs to [-1, 1] so make outputs [-1, 1]
        )

    def forward(self, x):
        return self.gen(x)

# %%
# Hyperparameters etc.
device = "cuda" if torch.cuda.is_available() else "cpu"
lr = 3e-4
z_dim = 64
image_dim = 28 * 28 * 1  # 784
batch_size = 32
num_epochs = 50

# %%
disc = Discriminator(image_dim).to(device)
gen = Generator(z_dim, image_dim).to(device)
fixed_noise = torch.randn((batch_size, z_dim)).to(device)
transforms = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
    ]
)

dataset = datasets.MNIST(root="dataset/", transform=transforms, download=True)
loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
opt_disc = optim.Adam(disc.parameters(), lr=lr)
opt_gen = optim.Adam(gen.parameters(), lr=lr)
criterion = nn.BCELoss()
writer_fake = SummaryWriter(f"logs/fake")
writer_real = SummaryWriter(f"logs/real")
step = 0

# %%
# Launch 5 simulated experiments
total_runs = 2
for run in range(total_runs):
  # 🐝 1️⃣ Start a new run to track this script
  wandb.init(
      # Set the project where this run will be logged
      project="basic-GAN", 
      # We pass a run name (otherwise it’ll be randomly assigned, like sunshine-lollypop-10)
      name=f"experiment_{run}", 
      # Track hyperparameters and run metadata
      config={
      "learning_rate": 0.0003,
      "architecture": "NN",
      "dataset": "MNIST",
      "epochs": 50,
      })
  
  # This simple block simulates a training loop logging metrics
  for epoch in range(num_epochs):
    for batch_idx, (real, _) in enumerate(loader):
        real = real.view(-1, 784).to(device)
        batch_size = real.shape[0]

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        noise = torch.randn(batch_size, z_dim).to(device)
        fake = gen(noise)
        disc_real = disc(real).view(-1)
        lossD_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake).view(-1)
        lossD_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        lossD = (lossD_real + lossD_fake) / 2
        disc.zero_grad()
        lossD.backward(retain_graph=True)
        opt_disc.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        # where the second option of maximizing doesn't suffer from
        # saturating gradients
        output = disc(fake).view(-1)
        lossG = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        lossG.backward()
        opt_gen.step()

        if batch_idx == 0:
            wandb.log({"epoch":epoch,"batch_idx":batch_idx, "loss_D": lossD, "loss_G": lossG})
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(loader)} \
                      Loss D: {lossD:.4f}, loss G: {lossG:.4f}"
            )

            with torch.no_grad():
                fake = gen(fixed_noise).reshape(-1, 1, 28, 28)
                data = real.reshape(-1, 1, 28, 28)
                # img_grid_fake = torchvision.utils.make_grid(fake, normalize=True)
                # img_grid_real = torchvision.utils.make_grid(data, normalize=True)
                fake_img = wandb.Image(fake)

                wandb.log({"images_fake": fake_img})
                # writer_fake.add_image(
                #     "Mnist Fake Images", img_grid_fake, global_step=step
                # )
                # writer_real.add_image(
                #     "Mnist Real Images", img_grid_real, global_step=step
                # )
                # step += 1
      
  # Mark the run as finished
  wandb.finish()
# Out:
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230414_030039-7bri7yol</code>
# Syncing run <strong><a href='https://wandb.ai/reneelin2020/basic-GAN/runs/7bri7yol' target="_blank">experiment_0</a></strong> to <a href='https://wandb.ai/reneelin2020/basic-GAN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/reneelin2020/basic-GAN' target="_blank">https://wandb.ai/reneelin2020/basic-GAN</a>
#  View run at <a href='https://wandb.ai/reneelin2020/basic-GAN/runs/7bri7yol' target="_blank">https://wandb.ai/reneelin2020/basic-GAN/runs/7bri7yol</a>
# Epoch [0/50] Batch 0/1875                       Loss D: 0.5930, loss G: 0.7047
# Epoch [1/50] Batch 0/1875                       Loss D: 0.8890, loss G: 0.7075
# Epoch [2/50] Batch 0/1875                       Loss D: 0.6323, loss G: 0.8811
# Epoch [3/50] Batch 0/1875                       Loss D: 0.9070, loss G: 0.6693
# Epoch [4/50] Batch 0/1875                       Loss D: 0.4699, loss G: 1.2590
# Epoch [5/50] Batch 0/1875                       Loss D: 0.2585, loss G: 1.8989
# Epoch [6/50] Batch 0/1875                       Loss D: 0.9006, loss G: 0.6634
# Epoch [7/50] Batch 0/1875                       Loss D: 0.4925, loss G: 1.2457
# Epoch [8/50] Batch 0/1875                       Loss D: 0.5818, loss G: 0.9829
# Epoch [9/50] Batch 0/1875                       Loss D: 1.0409, loss G: 0.7607
# Epoch [10/50] Batch 0/1875                       Loss D: 0.8918, loss G: 0.7114
# Epoch [11/50] Batch 0/1875                       Loss D: 0.4137, loss G: 1.5105
# Epoch [12/50] Batch 0/1875                       Loss D: 0.4524, loss G: 1.3835
# Epoch [13/50] Batch 0/1875                       Loss D: 0.3155, loss G: 1.7004
# Epoch [14/50] Batch 0/1875                       Loss D: 0.5801, loss G: 1.3021
# Epoch [15/50] Batch 0/1875                       Loss D: 0.5188, loss G: 1.4039
# Epoch [16/50] Batch 0/1875                       Loss D: 0.4720, loss G: 1.6371
# Epoch [17/50] Batch 0/1875                       Loss D: 0.4012, loss G: 1.7126
# Epoch [18/50] Batch 0/1875                       Loss D: 0.5923, loss G: 1.0815
# Epoch [19/50] Batch 0/1875                       Loss D: 0.6919, loss G: 1.6138
# Epoch [20/50] Batch 0/1875                       Loss D: 0.7054, loss G: 1.0008
# Epoch [21/50] Batch 0/1875                       Loss D: 0.6399, loss G: 0.9060
# Epoch [22/50] Batch 0/1875                       Loss D: 0.4282, loss G: 1.5806
# Epoch [23/50] Batch 0/1875                       Loss D: 0.5262, loss G: 1.2217
# Epoch [24/50] Batch 0/1875                       Loss D: 0.5828, loss G: 1.7507
# Epoch [25/50] Batch 0/1875                       Loss D: 0.4829, loss G: 1.3759
# Epoch [26/50] Batch 0/1875                       Loss D: 0.5902, loss G: 1.4215
# Epoch [27/50] Batch 0/1875                       Loss D: 0.5036, loss G: 1.4081
# Epoch [28/50] Batch 0/1875                       Loss D: 0.5157, loss G: 1.3623
# Epoch [29/50] Batch 0/1875                       Loss D: 0.5564, loss G: 1.0046
# Epoch [30/50] Batch 0/1875                       Loss D: 0.5720, loss G: 1.2463
# Epoch [31/50] Batch 0/1875                       Loss D: 0.3693, loss G: 1.9056
# Epoch [32/50] Batch 0/1875                       Loss D: 0.4261, loss G: 1.5557
# Epoch [33/50] Batch 0/1875                       Loss D: 0.5869, loss G: 1.2869
# Epoch [34/50] Batch 0/1875                       Loss D: 0.5775, loss G: 1.4763
# Epoch [35/50] Batch 0/1875                       Loss D: 0.6607, loss G: 1.1274
# Epoch [36/50] Batch 0/1875                       Loss D: 0.5573, loss G: 1.3396
# Epoch [37/50] Batch 0/1875                       Loss D: 0.6605, loss G: 1.0437
# Epoch [38/50] Batch 0/1875                       Loss D: 0.6681, loss G: 1.4640
# Epoch [39/50] Batch 0/1875                       Loss D: 0.5139, loss G: 1.4089
# Epoch [40/50] Batch 0/1875                       Loss D: 0.6206, loss G: 1.1787
# Epoch [41/50] Batch 0/1875                       Loss D: 0.6540, loss G: 1.2742
# Epoch [42/50] Batch 0/1875                       Loss D: 0.7871, loss G: 0.8895
# Epoch [43/50] Batch 0/1875                       Loss D: 0.6046, loss G: 0.9756
# Epoch [44/50] Batch 0/1875                       Loss D: 0.6833, loss G: 1.3808
# Epoch [45/50] Batch 0/1875                       Loss D: 0.6643, loss G: 1.0382
# Epoch [46/50] Batch 0/1875                       Loss D: 0.6152, loss G: 1.1554
# Epoch [47/50] Batch 0/1875                       Loss D: 0.7026, loss G: 0.9938
# Epoch [48/50] Batch 0/1875                       Loss D: 0.6056, loss G: 1.1336
# Epoch [49/50] Batch 0/1875                       Loss D: 0.5597, loss G: 1.1203
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.822 MB of 1.822 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_idx</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_D</td><td>▅█▅█▁█▄▄█▃▃▂▄▃▃▅▆▅▃▄▃▅▄▄▄▂▃▅▅▄▅▅▅▅▇▅▅▅▆▄</td></tr><tr><td>loss_G</td><td>▁▁▂▁█▁▄▃▁▆▅▇▅▆▇▃▃▂▆▄▅▅▅▅▄█▆▅▄▅▃▆▄▄▂▃▃▄▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_idx</td><td>0</td></tr><tr><td>epoch</td><td>49</td></tr><tr><td>loss_D</td><td>0.55968</td></tr><tr><td>loss_G</td><td>1.12033</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_0</strong> at: <a href='https://wandb.ai/reneelin2020/basic-GAN/runs/7bri7yol' target="_blank">https://wandb.ai/reneelin2020/basic-GAN/runs/7bri7yol</a><br/>Synced 5 W&B file(s), 50 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230414_030039-7bri7yol/logs</code>
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230414_032958-i5h0ysu4</code>
# Syncing run <strong><a href='https://wandb.ai/reneelin2020/basic-GAN/runs/i5h0ysu4' target="_blank">experiment_1</a></strong> to <a href='https://wandb.ai/reneelin2020/basic-GAN' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/reneelin2020/basic-GAN' target="_blank">https://wandb.ai/reneelin2020/basic-GAN</a>
#  View run at <a href='https://wandb.ai/reneelin2020/basic-GAN/runs/i5h0ysu4' target="_blank">https://wandb.ai/reneelin2020/basic-GAN/runs/i5h0ysu4</a>
# Epoch [0/50] Batch 0/1875                       Loss D: 0.5575, loss G: 1.0861
# Epoch [1/50] Batch 0/1875                       Loss D: 0.4913, loss G: 1.2609
# Epoch [2/50] Batch 0/1875                       Loss D: 0.5731, loss G: 1.2958
# Epoch [3/50] Batch 0/1875                       Loss D: 0.6185, loss G: 0.8986
# Epoch [4/50] Batch 0/1875                       Loss D: 0.6025, loss G: 0.9673
# Epoch [5/50] Batch 0/1875                       Loss D: 0.8016, loss G: 0.7294
# Epoch [6/50] Batch 0/1875                       Loss D: 0.8113, loss G: 0.9677
# Epoch [7/50] Batch 0/1875                       Loss D: 0.5424, loss G: 1.2366
# Epoch [8/50] Batch 0/1875                       Loss D: 0.6061, loss G: 1.0007
# Epoch [9/50] Batch 0/1875                       Loss D: 0.6339, loss G: 1.0671
# Epoch [10/50] Batch 0/1875                       Loss D: 0.5924, loss G: 1.2110
# Epoch [11/50] Batch 0/1875                       Loss D: 0.6130, loss G: 1.0099
# Epoch [12/50] Batch 0/1875                       Loss D: 0.5934, loss G: 1.0472
# Epoch [13/50] Batch 0/1875                       Loss D: 0.6011, loss G: 0.9811
# Epoch [14/50] Batch 0/1875                       Loss D: 0.6686, loss G: 1.0165
# Epoch [15/50] Batch 0/1875                       Loss D: 0.8674, loss G: 0.7989
# Epoch [16/50] Batch 0/1875                       Loss D: 0.5287, loss G: 1.0307
# Epoch [17/50] Batch 0/1875                       Loss D: 0.7094, loss G: 0.8966
# Epoch [18/50] Batch 0/1875                       Loss D: 0.7135, loss G: 0.8702
# Epoch [19/50] Batch 0/1875                       Loss D: 0.6115, loss G: 0.9203
# Epoch [20/50] Batch 0/1875                       Loss D: 0.5554, loss G: 1.1891
# Epoch [21/50] Batch 0/1875                       Loss D: 0.6282, loss G: 0.9774
# Epoch [22/50] Batch 0/1875                       Loss D: 0.6109, loss G: 1.0138
# Epoch [23/50] Batch 0/1875                       Loss D: 0.7245, loss G: 0.8831
# Epoch [24/50] Batch 0/1875                       Loss D: 0.6836, loss G: 0.8649
# Epoch [25/50] Batch 0/1875                       Loss D: 0.6775, loss G: 0.9454
# Epoch [26/50] Batch 0/1875                       Loss D: 0.6675, loss G: 0.8060
# Epoch [27/50] Batch 0/1875                       Loss D: 0.6289, loss G: 1.0867
# Epoch [28/50] Batch 0/1875                       Loss D: 0.6262, loss G: 0.9237
# Epoch [29/50] Batch 0/1875                       Loss D: 0.5522, loss G: 0.9452
# Epoch [30/50] Batch 0/1875                       Loss D: 0.5958, loss G: 0.9971
# Epoch [31/50] Batch 0/1875                       Loss D: 0.5626, loss G: 1.2177
# Epoch [32/50] Batch 0/1875                       Loss D: 0.6888, loss G: 1.1309
# Epoch [33/50] Batch 0/1875                       Loss D: 0.6397, loss G: 0.9608
# Epoch [34/50] Batch 0/1875                       Loss D: 0.5054, loss G: 1.0258
# Epoch [35/50] Batch 0/1875                       Loss D: 0.6455, loss G: 0.8835
# Epoch [36/50] Batch 0/1875                       Loss D: 0.6479, loss G: 0.9589
# Epoch [37/50] Batch 0/1875                       Loss D: 0.5229, loss G: 1.0018
# Epoch [38/50] Batch 0/1875                       Loss D: 0.6322, loss G: 1.0049
# Epoch [39/50] Batch 0/1875                       Loss D: 0.6094, loss G: 1.0754
# Epoch [40/50] Batch 0/1875                       Loss D: 0.5767, loss G: 0.9434
# Epoch [41/50] Batch 0/1875                       Loss D: 0.6919, loss G: 0.8885
# Epoch [42/50] Batch 0/1875                       Loss D: 0.6901, loss G: 0.7912
# Epoch [43/50] Batch 0/1875                       Loss D: 0.6285, loss G: 0.9046
# Epoch [44/50] Batch 0/1875                       Loss D: 0.5796, loss G: 1.2126
# Epoch [45/50] Batch 0/1875                       Loss D: 0.6756, loss G: 0.8138
# Epoch [46/50] Batch 0/1875                       Loss D: 0.5843, loss G: 0.9892
# Epoch [47/50] Batch 0/1875                       Loss D: 0.6148, loss G: 0.8826
# Epoch [48/50] Batch 0/1875                       Loss D: 0.5806, loss G: 1.1228
# Epoch [49/50] Batch 0/1875                       Loss D: 0.7326, loss G: 0.8527
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.192 MB of 1.199 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.993963…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch_idx</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss_D</td><td>▂▁▃▃▇▇▂▃▃▃▃▃█▂▅▅▂▄▃▅▄▄▄▄▃▂▅▄▄▄▂▄▃▅▅▄▄▃▃▅</td></tr><tr><td>loss_G</td><td>▅██▃▁▄▇▄▇▄▅▄▂▅▃▃▇▄▅▃▄▂▅▃▄▇▆▄▃▄▄▄▄▃▂▃▂▄▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch_idx</td><td>0</td></tr><tr><td>epoch</td><td>49</td></tr><tr><td>loss_D</td><td>0.7326</td></tr><tr><td>loss_G</td><td>0.85272</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">experiment_1</strong> at: <a href='https://wandb.ai/reneelin2020/basic-GAN/runs/i5h0ysu4' target="_blank">https://wandb.ai/reneelin2020/basic-GAN/runs/i5h0ysu4</a><br/>Synced 5 W&B file(s), 50 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230414_032958-i5h0ysu4/logs</code>
